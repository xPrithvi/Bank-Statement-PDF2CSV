# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
from typing import List
from pypdf import PdfReader

# Langchain,
from langchain_community.chat_models import ChatOllama
from langchain_community.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

# %% [markdown]
# ### Extracting from PDF

# %%
# Opening PDF,
reader = PdfReader("statement.pdf")
n_pages = len(reader.pages)

# Extracting all text from the PDF,
pdf_text = ""
for i in range(n_pages):
    page = reader.pages[i]
    page_text = page.extract_text()
    pdf_text += page_text

# %%
import pymupdf # imports the pymupdf library

pdf_text = ""
doc = pymupdf.open("statement.pdf") # open a document
for page in doc: # iterate the document pages
  text = page.get_text() # get plain text encoded as UTF-8
  pdf_text += text

# %% [markdown]
# ### Model Wrapper

# %%
# Wrapping around LLM,
TEMPERATURE = 0.05
KEY = ""
os.environ["OPENAI_API_KEY"] = KEY
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=TEMPERATURE)

# %% [markdown]
# ### Prompt Engineering

# %%
# Creating schema for LLM output,
class Transaction(BaseModel):
    date: str = Field(description="The date the transaction occured.")
    description: str = Field(description="The description of the transcation. Includes the person/organisation involves, the reference and sometimes the location. Do NOT include the transaction type.")
    type: str = Field(description="The type of transaction. Sometimes given as a code.")
    paid_in: float = Field(description="Money paid IN the account.")
    paid_out: float = Field(description="Money paid OUT of the account.")

class Summary(BaseModel):
    opening_balance: float
    payments_in: float
    payments_out: float
    closing_balance: float

class OutputWrapper(BaseModel):
    summary: Summary
    transactions: List[Transaction]

# Creating parser,
parser = PydanticOutputParser(pydantic_object=OutputWrapper)

# Generating formatting instructions from schemas,
format_instructions = parser.get_format_instructions()

# Creating the LLM prompt,
PROMPT = f"""You have been given raw text that has been extracted from the PDF of a bank statement. Extract the balance summary and transactions 
             details structured in JSON with the following schema: {format_instructions}. The statement text is: {pdf_text}. RESPOND ONLY IN JSON FORMAT"""

PROMPT
# Out:
# 'You have been given raw text that has been extracted from the PDF of a bank statement. Extract the balance summary and transactions \n             details structured in JSON with the following schema: The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"$defs": {"Summary": {"properties": {"opening_balance": {"title": "Opening Balance", "type": "number"}, "payments_in": {"title": "Payments In", "type": "number"}, "payments_out": {"title": "Payments Out", "type": "number"}, "closing_balance": {"title": "Closing Balance", "type": "number"}}, "required": ["opening_balance", "payments_in", "payments_out", "closing_balance"], "title": "Summary", "type": "object"}, "Transaction": {"properties": {"date": {"description": "The date the transaction occured.", "title": "Date", "type": "string"}, "description": {"description": "The description of the transcation. Includes the person/organisation involves, the reference and sometimes the location. Do NOT include the transaction type.", "title": "Description", "type": "string"}, "type": {"description": "The type of transaction. Sometimes given as a code.", "title": "Type", "type": "string"}, "paid_in": {"description": "Money paid IN the account.", "title": "Paid In", "type": "number"}, "paid_out": {"description": "Money paid OUT of the account.", "title": "Paid Out", "type": "number"}}, "required": ["date", "description", "type", "paid_in", "paid_out"], "title": "Transaction", "type": "object"}}, "properties": {"summary": {"$ref": "#/$defs/Summary"}, "transactions": {"items": {"$ref": "#/$defs/Transaction"}, "title": "Transactions", "type": "array"}}, "required": ["summary", "transactions"]}\n```. The statement text is: Starling Bank is registered in England and Wales as Starling Bank Limited (No. 09092149), 5th Floor, London Fruit and Wool Exchange, 1 Duval Square, London, \nE1 6PW. We are authorised by the Prudential Regulation Authority and regulated by the Financial Conduct Authority and the Prudential Regulation Authority under \nregistration number 730166.\nOur terms and conditions can be accessed via the Starling app or by our website www.starlingbank.com/legal\nStarling Bank Limited is a member of the Financial Services Compensation Scheme and the Financial Ombudsman Service. For further information about the \ncompensation provided by the FSCS, refer to the FSCS website at www.fscs.org.uk. Further details can also be found on the FSCS Information Sheet and Exclusions \nList which are available in the app and on our website.\n24hr Customer Service: 0207 930 4450\nwww.starlingbank.com\nMr Prithvi Ramrucha\n61 Bakewell Drive\nNOTTINGHAM\nNottinghamshire\nNG5 9AE\nPrithvi Ramrucha\nGB31SRLG60837102904998\nSRLGGB2L\n60-83-71\n02904998\nAccount Name:\nIBAN:\nBIC:\nSort code:\nAccount Number:\nSummary\n01/01/2024 - 31/01/2024\nOpening Balance\n£67.66\nPayments In\n£428.36\nPayments Out\n£376.28\nClosing Balance\n£119.74\nYour deposit is eligible for protection by the\nFinancial Services Compensation Scheme.\nJanuary 2024 Statement\nDATE\nTYPE\nTRANSACTION\nIN\nOUT\nEND OF DAY\nACCOUNT\nBALANCE\nOPENING BALANCE\n£67.66\n01/01/2024\nDEPOSIT INTEREST\nStarling Bank (December Interest Earned)\n£0.36\n01/01/2024\nFASTER PAYMENT\nRAMRUCHA P (mum - new yrs gift)\n£50.00\n£118.02\n02/01/2024\nFASTER PAYMENT\nRAMRUCHA (dad)\n£13.00\n£131.02\n03/01/2024\nONLINE PAYMENT\nAmazon Marketplace\n£12.99\n£118.03\n04/01/2024\nATM\nCash Machine\n£10.00\n04/01/2024\nCONTACTLESS\nCo-op\n£8.20\n04/01/2024\nCONTACTLESS\nCo-op\n£7.20\n£92.63\n06/01/2024\nCONTACTLESS\nTesco\n£38.32\n£54.31\n07/01/2024\nCONTACTLESS ...

# %% [markdown]
# ### Chain

# %%
# Sending prompt to LLM,
response = llm.invoke([HumanMessage(content=PROMPT)])

# Parsing LLM output,
parsed_response = parser.parse(response.content)

# Creating dataframe and converting to CSV,
df = pd.DataFrame([transcation.model_dump() for transcation in parsed_response.transactions])

# Calculating closing balance after each transaction,
opening_balance = dict(parsed_response.summary)["opening_balance"]
closing_balance_vals = [opening_balance]

for index, row in df.iterrows():
    closing_balance_val = round(closing_balance_vals[-1] + row["paid_in"] - row["paid_out"], 2)
    closing_balance_vals.append(closing_balance_val)
closing_balance_vals.pop(0)

df["closing_balance"] = closing_balance_vals

# Printing,
print(dict(parsed_response.summary))
df
# Out:
# {'opening_balance': 67.66, 'payments_in': 428.36, 'payments_out': 376.28, 'closing_balance': 119.74}
#           date                                        description  \
# 0   01/01/2024  DEPOSIT INTEREST Starling Bank (December Inter...
# 1   01/01/2024     FASTER PAYMENT RAMRUCHA P (mum - new yrs gift)
# 2   02/01/2024                      FASTER PAYMENT RAMRUCHA (dad)
# 3   03/01/2024                  ONLINE PAYMENT Amazon Marketplace
# 4   04/01/2024                                   ATM Cash Machine
# 5   04/01/2024                                  CONTACTLESS Co-op
# 6   04/01/2024                                  CONTACTLESS Co-op
# 7   06/01/2024                                  CONTACTLESS Tesco
# 8   07/01/2024                                  CONTACTLESS Co-op
# 9   10/01/2024                                  CONTACTLESS Co-op
# 10  10/01/2024                                  CONTACTLESS Co-op
# 11  10/01/2024  FASTER PAYMENT Prithvi Ramrucha (HSBC) (Starli...
# 12  11/01/2024                          ONLINE PAYMENT Circuit Uk
# 13  11/01/2024                                  CONTACTLESS Co-op
# 14  11/01/2024                                  CONTACTLESS Co-op
# 15  13/01/2024                                  CONTACTLESS Co-op
# 16  14/01/2024                                  CONTACTLESS Co-op
# 17  14/01/2024                      FASTER PAYMENT RAMRUCHA (dad)
# 18  17/01/2024                          ONLINE PAYMENT Circuit Uk
# 19  17/01/2024                                  CONTACTLESS Co-op
# 20  18/01/2024                                  CONTACTLESS Co-op
# 21  18/01/2024                                  CONTACTLESS Co-op
# 22  19/01/2024                                  CONTACTLESS Co-op
# 23  19/01/2024                                  CONTACTLESS Co-op
# 24  20/01/2024                                  CONTACTLESS Co-op
# 25  20/01/2024                                  CONTACTLESS Co-op
# 26  20/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 27  22/01/2024                                  CONTACTLESS Co-op
# 28  23/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 29  23/01/2024                            ONLINE PAYMENT Just Eat
# 30  23/01/2024             FASTER PAYMENT S W KOKULANATHAN (food)
# 31  24/01/2024                          CARD SUBSCRIPTION Spotify
# 32  26/01/2024                              ONLINE PAYMENT Amazon
# 33  27/01/2024                                   ATM Cash Machine
# 34  27/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 35  27/01/2024                                  CONTACTLESS Co-op
# 36  27/01/2024                                  CONTACTLESS Co-op
# 37  28/01/2024                                  CONTACTLESS Tesco
# 38  29/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 39  29/01/2024                          ONLINE PAYMENT Circuit Uk
# 40  29/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 41  30/01/2024                                  CONTACTLESS Co-op
# 42  30/01/2024                          CONTACTLESS Portland Spar
# 43  30/01/2024                              ONLINE PAYMENT Amazon
# 44  30/01/2024                    FASTER PAYMENT RAMRUCHA P (mum)
# 45  31/01/2024                                  CONTACTLESS Co-op
#
#                  type  paid_in  paid_out  closing_balance
# 0    DEPOSIT INTEREST     0.36      0.00            68.02
# 1      FASTER PAYMENT    50.00      0.00           118.02
# 2      FASTER PAYMENT     0.00     13.00           105.02
# 3      ONLINE PAYMENT     0.00     12.99            92.03
# 4                 ATM     0.00     10.00            82.03
# 5         CONTACTLESS     0.00      8.20            73.83
# 6         CONTACTLESS     0.00      7.20            66.63
# 7         CONTACTLESS     0.00     38.32            28.31
# 8         CONTACTLESS     0.00      3.25            25.06
# 9         CONTACTLESS     0.00      9.05            16.01
# 10        CONTACTLESS     0.00      3.50            12.51
# 11     FASTER PAYMENT    50.00      0.00            62.51
# 12     ONLINE PAYMENT     0.00      8.00            54.51
# 13        CONTACTLESS     0.00      1.89            52.62
# 14        CONTACTLESS     0.00     10.35            42.27
# 15        CONTACTLESS     0.00      6.95            35.32
# 16        CONTACTLESS     0.00      6.60            28.72
# 17     FASTER PAYMENT    49.00      0.00            77.72
# 18     ONLINE PAYMENT     0.00      8.00            69.72
# 19        CONTACTLESS     0.00     14.73            54.99
# 20        CONTACTLESS     0.00      3.50            51.49
# 21        CONTACTLESS     0.00     11.30            40.19
# 22        CONTACTLESS     0.00      3.40            36.79
# 23        CONTACTLESS     0.00      8.99            27.80
# 24        CONTACTLESS     0.00      4.50            23.30
# 25        CONTACTLESS     0.00      6.65            16.65
# 26     FASTER PAYMENT    25.00      0.00            41.65
# 27        CONTACTLESS     0.00     15.80            25.85
# 28     FASTER PAYMENT    75.00      0.00           100.85
# 29     ONLINE PAYMENT     0.00     23.83            77.02
# 30     FASTER PAYMENT    17.50      0.00            94.52
# 31  CARD SUBSCRIPTION     0.00      5.99            88.53
# 32     ONLINE PAYMENT     0.00     23.96            64.57
# 33                ATM     0.00     10.00            54.57
# 34     FASTER PAYMENT    15.00      0.00            69.57
# 35        CONTACTLESS     0.00     10.00            59.57
# 36        CONTACTLESS     0.00      6.80            52.77
# 37        CONTACTLESS     0.00     29.48            23.29
# 38     FASTER PAYMENT   100.00      0.00           123.29
# 39     ONLINE PAYMENT     0.00      5.00           118.29
# 40     FASTER PAYMENT    21.00      0.00           139.29
# 41        CONTACTLESS     0.00     12.40           126.89
# 42        CONTACTLESS     0.00      4.25           122.64
# 43     ONLINE PAYMENT     0.00     17.95           104.69
# 44     FASTER PAYMENT    30.00      0.00           134.69
# 45        CONTACTLESS     0.00      5.95           128.74
